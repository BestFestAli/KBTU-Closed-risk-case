# %% [markdown]
# # Risk Management
# # Case Competition
# ## I tour

# %%
import numpy as np
import pandas as pd

train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
train_corr = train.corr()['target'].sort_values(ascending=False)
print(train_corr)
# Out:
# target    1.000000
# V10       0.234229
# V12       0.168100
# V21       0.152429
# V19       0.131519
# V17       0.130899
# V8        0.111304
# V7        0.106893
# V9        0.098017
# V18       0.070206
# male      0.055503
# V11       0.051979
# V15       0.044790
# V1        0.037899
# V20       0.013327
# V16       0.005008
# V3        0.002910
# V4       -0.009451
# V2       -0.028472
# V5       -0.034242
# V14      -0.066823
# V6       -0.079594
# V13      -0.079638
# age      -0.083560
# Name: target, dtype: float64

# %%
X = pd.DataFrame(data=train, columns=train.columns.drop("target"))
y = pd.DataFrame(data=train, columns=["target"] )
X
# Out:
#         age  male         V1          V2          V3         V4         V5  \
# 0        66     0   73595.06        0.00    73595.06   343870.0   689472.0
# 1        21     1  954302.98        0.00   954302.98   999584.0   510000.0
# 2        52     0   50000.00  1216163.56  1266163.56  2278000.0  2053000.0
# 3        31     1   71981.79        0.00    71981.79   200000.0  2692250.0
# 4        53     0  274132.79        0.00   274132.79   625430.0   400000.0
# ...     ...   ...        ...         ...         ...        ...        ...
# 999995   32     0   68562.00        0.00    68562.00   129970.0   129970.0
# 999996   25     1  541714.30        0.00   541714.30   748045.0   398155.0
# 999997   41     0  749973.00        0.00   749973.00  1200000.0  1200000.0
# 999998   31     0   38496.00        0.00    38496.00    76998.0   279107.0
# 999999   45     1  214232.00  1218337.00  1432569.00  2065490.0  1837500.0
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sbn

for vnum in range(0,23):
    plt.figure(figsize= (18,8))
    sbn.histplot(x=X[cols[vnum]])
    plt.title('var = {}'.format(cols[vnum]))
# Out:
# C:\Users\am429\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\am429\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
plt.bar(X['V21'], )

# %%
plt.figure(figsize= (18,12))

for vnum in range(7,13):
    sbn.histplot(x=X[cols[vnum]])
    plt.subplot(2,3,vnum)
    plt.title('var = {}'.format(vnum))
# Out:
# C:\Users\am429\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\am429\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\am429\Desktop\Risk Management\Case.ipynb Cell 12 line 5
# ...

# %%
plt.figure(figsize= (18,12))

for vnum in range(19,22):
    sbn.histplot(x=X[cols[vnum+1]])
    plt.subplot(2,3,vnum)
    plt.title('var = {}'.format(vnum))

# %%
plt.figure(figsize= (18,8))

for vnum in range(7,13):
    sbn.histplot(x=X[cols[vnum+1]])
    plt.subplot(1,3,vnum)
    plt.title('var = {}'.format(vnum))

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor 


knn_model = KNeighborsRegressor()
tree_model = DecisionTreeRegressor(random_state = 500149)
forest_model = RandomForestRegressor(n_estimators=100, random_state = 500149)


knn_model.fit(X,y)
tree_model.fit(X,y)
forest_model.fit(X,y)
# Out:
# C:\Users\am429\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %%
from sklearn.linear_model import LinearRegression
line_model = LinearRegression()
line_model.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\am429\Desktop\Risk Management\Case.ipynb Cell 7 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/am429/Desktop/Risk%20Management/Case.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> from sklearn.linear_model import LinearRegression
#       <a href='vscode-notebook-cell:/c%3A/Users/am429/Desktop/Risk%20Management/Case.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> line_model = LinearRegression()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/am429/Desktop/Risk%20Management/Case.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a> line_model.fit(X,y)
#
# NameError: name 'X' is not defined
